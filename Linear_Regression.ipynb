# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Sagar Kandpal\Desktop\ML EXAMPLE\Modular\ML_Live_Class\data\Advertising.csv")
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df['total_spent'] = df['TV'] + df['radio'] + df['newspaper']
sns.scatterplot(data=df, x='total_spent', y='sales')
# Out:
# <AxesSubplot:xlabel='total_spent', ylabel='sales'>

# %%
sns.regplot(data=df, x='total_spent', y='sales', color='g') #seaborn is able to draw a regression line using OLS
# Out:
# <AxesSubplot:xlabel='total_spent', ylabel='sales'>

# %%
x = df['total_spent']
y = df['sales']

# %%
np.polyfit(x,y, deg=1) #it's a polynomial fit based on non linear least squares or ordinary least squares
#This function uses least squares and the solution is to minimize the squared errors in the given polynomial.
# Out:
# array([0.04868788, 4.24302822])

# %%
#Numpy.polyfit and Scikit-learn.LinearRegression with PolynomialFeatures might be used interchangeably because those return the same coefficients and intercepts

# %%
potential_spend = np.linspace(0,500,100)

# %%
predicted_sales = 0.04868788*potential_spend + 4.24302822

# %%
sns.scatterplot(x='total_spent', y= 'sales', data= df)
plt.plot(potential_spend, predicted_sales, color = 'red')

# %%
spend = 200
predicted_sales = 0.04868788*spend + 4.24302822
predicted_sales
# Out:
# 13.98060422

# %%
predicted_sales = 0.04868788*potential_spend + 4.24302822
predicted_sales
# Out:
# array([ 4.24302822,  4.4889266 ,  4.73482499,  4.98072337,  5.22662176,
#         5.47252014,  5.71841852,  5.96431691,  6.21021529,  6.45611367,
#         6.70201206,  6.94791044,  7.19380883,  7.43970721,  7.68560559,
#         7.93150398,  8.17740236,  8.42330075,  8.66919913,  8.91509751,
#         9.1609959 ,  9.40689428,  9.65279266,  9.89869105, 10.14458943,
#        10.39048782, 10.6363862 , 10.88228458, 11.12818297, 11.37408135,
#        11.61997974, 11.86587812, 12.1117765 , 12.35767489, 12.60357327,
#        12.84947165, 13.09537004, 13.34126842, 13.58716681, 13.83306519,
#        14.07896357, 14.32486196, 14.57076034, 14.81665873, 15.06255711,
#        15.30845549, 15.55435388, 15.80025226, 16.04615064, 16.29204903,
#        16.53794741, 16.7838458 , 17.02974418, 17.27564256, 17.52154095,
#        17.76743933, 18.01333771, 18.2592361 , 18.50513448, 18.75103287,
#        18.99693125, 19.24282963, 19.48872802, 19.7346264 , 19.98052479,
# ...

# %%
np.polyfit(x,y,deg=3) #these are theta values for this polynomial fit
# Out:
# array([ 3.07615033e-07, -1.89392449e-04,  8.20886302e-02,  2.70495053e+00])

# %%
#y = B1x + B0

#Y B3x**3 + B2*x**2 + B1x + B0

pot_spend = np.linspace(0,500,100)

# %%
pred_sales = 3.07615033e-07*pot_spend**3 + -1.89392449e-04*pot_spend**2 + 8.20886302e-02*pot_spend + 2.70495053e+00
pred_sales
# Out:
# array([ 2.70495053,  3.11474825,  3.51512186,  3.90630911,  4.28854779,
#         4.66207567,  5.02713053,  5.38395013,  5.73277224,  6.07383466,
#         6.40737513,  6.73363145,  7.05284138,  7.3652427 ,  7.67107318,
#         7.97057059,  8.2639727 ,  8.5515173 ,  8.83344215,  9.10998503,
#         9.38138371,  9.64787596,  9.90969955, 10.16709227, 10.42029188,
#        10.66953616, 10.91506288, 11.15710981, 11.39591473, 11.63171541,
#        11.86474963, 12.09525515, 12.32346975, 12.54963121, 12.77397729,
#        12.99674578, 13.21817443, 13.43850104, 13.65796337, 13.87679919,
#        14.09524628, 14.31354241, 14.53192536, 14.75063289, 14.96990278,
#        15.18997281, 15.41108075, 15.63346437, 15.85736144, 16.08300974,
#        16.31064705, 16.54051112, 16.77283975, 17.0078707 , 17.24584174,
#        17.48699065, 17.73155521, 17.97977318, 18.23188233, 18.48812045,
#        18.74872531, 19.01393467, 19.28398632, 19.55911802, 19.83956755,
# ...

# %%
sns.scatterplot(x='total_spent', y= 'sales', data= df)
plt.plot(pot_spend, pred_sales, color = 'red')

# %%
fig,axes = plt.subplots(nrows=1, ncols=3, figsize=(16,6))

axes[0].plot(df['TV'], df['sales'], 'o')
axes[0].set_ylabel("Sales")
axes[0].set_title("TV Spend")

axes[1].plot(df['radio'], df['sales'], 'o')
axes[1].set_ylabel("Sales")
axes[1].set_title("Radio Spend")

axes[2].plot(df['newspaper'], df['sales'], 'o')
axes[2].set_ylabel("Sales")
axes[2].set_title("newspaper Spend")
#plt.tight_layout()
# Out:
# Text(0.5, 1.0, 'newspaper Spend')

# %%
sns.pairplot(df)

# %%
x = df.drop(['sales','total_spent'], axis=1)
x
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y = df['sales']
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: sales, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
                                    x, y, test_size=0.33, random_state=101)

# %%
from sklearn.linear_model import LinearRegression
#help(LinearRegression)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
test_pred = model.predict(X_test)
test_pred
# Out:
# array([15.64343813, 19.58078283, 11.42717781, 16.90494334,  9.17645232,
#         7.01921001, 20.24548588, 17.27288092,  9.81362002, 19.15221858,
#        12.36281849, 13.90086335, 13.74679921, 21.16322282, 18.31876004,
#         9.96472602, 15.56312703,  7.73452007,  7.57314037, 20.32745421,
#         7.79414911, 18.16308067, 24.57041484, 22.71055089,  8.01558318,
#        12.65730219, 21.43661308,  8.04499619, 12.43159447, 12.40259255,
#        10.70029092, 19.16776811, 10.10150532,  6.69083331, 17.24889776,
#         7.79224406,  9.25952001,  8.31516806, 10.51963092, 10.67086792,
#        12.88094679,  9.79344981, 10.20060813,  8.013982  , 11.54267429,
#        10.07800983,  8.98583386, 16.21285502, 13.20750313, 20.70094692,
#        12.42670309, 13.96572233, 17.55475937, 11.15936616, 12.58108647,
#         5.54230087, 23.22486082, 12.58536565, 18.76366836, 15.15376302,
#        15.15931391, 23.91773675,  6.78191588, 19.84529505, 13.86858162,
#        21.07676645])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
df['sales'].mean() #average of sales
# Out:
# 14.0225

# %%
sns.histplot(data=df, x='sales', bins=20) #distribution of sales
# Out:
# <AxesSubplot:xlabel='sales', ylabel='Count'>

# %%
mean_absolute_error(y_test, test_pred)
# Out:
# 1.236918849425931

# %%
mean_squared_error(y_test, test_pred)
# Out:
# 2.348375242713827

# %%
np.sqrt(mean_squared_error(y_test, test_pred))
# Out:
# 1.532440942651242

# %%
"""If there is lot of difference between MAE and RMSE then it means your model is performing well on most of the points nearby but not far away points.
"""
# Out:
# 'If there is lot of difference between MAE and RMSE then it means your model is performing well on most of the points nearby but not far away points.\n'

# %%
test_residuals = y_test - test_pred
test_residuals
# Out:
# 37    -0.943438
# 109    0.219217
# 31     0.472822
# 89    -0.204943
# 66     0.323548
#          ...
# 183    2.282263
# 127    2.018084
# 53     1.354705
# 100   -2.168582
# 93     1.123234
# Name: sales, Length: 66, dtype: float64

# %%
sns.scatterplot(x=y_test, y=test_residuals)
#it looks like random, no pattern in the residual plot can be seen so linear regression can be used
plt.axhline(y=0, color='red', ls='--')

# %%
sns.displot(test_residuals, bins=25, kde=True) #kernel density estimation

# %%
model.coef_   #theta coefficients for different features, newspaper coefficient is almost zero so it dosen't contribute much for the sales(it will reduce the sales),
#radio coeffiecient is the strongest, if you spend on it then it will show increase in sales 0.185 times, keeping TV and newspaper expenditure constant
# Out:
# array([ 0.04458371,  0.18525166, -0.00122463])

# %%
y_hat = model.predict(x)

# %%
fig,axes = plt.subplots(nrows=1, ncols=3, figsize=(16,6))

axes[0].plot(df['TV'], df['sales'], 'o')
axes[0].plot(df['TV'], y_hat, 'o', color='red')
axes[0].set_ylabel("Sales")
axes[0].set_title("TV Spend")

axes[1].plot(df['radio'], df['sales'], 'o')
axes[1].plot(df['radio'],y_hat, 'o', color='red')
axes[1].set_ylabel("Sales")
axes[1].set_title("Radio Spend")

axes[2].plot(df['newspaper'], df['sales'], 'o')
axes[2].plot(df['newspaper'],y_hat, 'o', color='red')
axes[2].set_ylabel("Sales")
axes[2].set_title("Newspaper spend")
# Out:
# Text(0.5, 1.0, 'Newspaper spend')

# %%
from joblib import dump,load #saving your file as a binary file

# %%
import os

# %%
model_dir = "models"
os.makedirs(model_dir, exist_ok=True)
filepath = os.path.join(model_dir, 'model.joblib')
dump(model, filepath)
# Out:
# ['models\\model.joblib']

# %%
load_model = load(r'C:\Users\Sagar Kandpal\Desktop\ML EXAMPLE\Modular\ML_Live_Class\models\model.joblib')

# %%
load_model.coef_
# Out:
# array([ 0.04458371,  0.18525166, -0.00122463])

# %%
example = [[151,25,15]]

# %%
load_model.predict(example)
# Out:
# C:\Users\Sagar Kandpal\anaconda3\envs\mltest\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([14.56263118])

# %% [markdown]
# # Polynomial Regression

# %%
x1 = df.drop(['sales', 'total_spent'], axis=1)
x1.head()
# Out:
#       TV  radio  newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
x1.shape
# Out:
# (200, 3)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly_conv = PolynomialFeatures(degree=2, include_bias=False)

# %%
poly_conv.fit(x1)
# Out:
# PolynomialFeatures(include_bias=False)

# %%
poly_features = poly_conv.transform(x1)

# %%
poly_features.shape
# Out:
# (200, 9)

# %%
x1.iloc[0]
# Out:
# TV           230.1
# radio         37.8
# newspaper     69.2
# Name: 0, dtype: float64

# %%
poly_features[0]
# Out:
# array([2.301000e+02, 3.780000e+01, 6.920000e+01, 5.294601e+04,
#        8.697780e+03, 1.592292e+04, 1.428840e+03, 2.615760e+03,
#        4.788640e+03])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
                                    poly_features, y, test_size=0.33, random_state=101)

# %%
model1 = LinearRegression()

# %%
model1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
test_pred = model1.predict(X_test)
test_pred
# Out:
# array([13.97204613, 19.31163632, 12.34937446, 16.77918795,  7.86585082,
#         6.91555804, 20.11299294, 17.49707854, 10.56626076, 20.12510306,
#         9.45653268, 14.08673516, 12.06855682, 23.37172536, 19.67600099,
#         9.14838427, 12.13661295,  9.25938961,  8.42727726, 21.64817709,
#         7.0207988 , 19.36930318, 27.21526812, 24.54515558,  8.98640103,
#        11.86761484, 20.38278449,  9.22102483, 12.76121768,  8.64739673,
#         8.67463214, 20.20034879, 10.93174941,  6.85739529, 18.29226844,
#         9.5074497 , 10.35219229,  9.64459655,  7.4384789 , 11.03480643,
#        12.66080843, 10.69057937, 11.23958513,  7.4725002 , 11.38637684,
#        10.2667274 ,  6.12707279, 15.54892762, 13.43339421, 22.70762962,
#        10.41887348, 13.24665286, 14.2399427 , 11.85682389, 11.71631169,
#         5.5519889 , 25.01544605,  9.5463153 , 17.34861031, 15.7728373 ,
#        15.51033662, 25.57307088,  8.60367331, 21.60788857, 12.34127765,
#        22.21531611])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
MAE = mean_absolute_error(y_test, test_pred)
MAE
# Out:
# 0.4842810535215552

# %%
MSE = mean_squared_error(y_test, test_pred)
MSE
# Out:
# 0.4202814842156936

# %%
RMSE = np.sqrt(MSE)
RMSE
# Out:
# 0.6482912032533633

# %%
model1.coef_
# Out:
# array([ 5.25319441e-02,  1.42773271e-02,  1.47528851e-02, -1.12739168e-04,
#         1.13231490e-03, -5.42180033e-05,  6.26813126e-05,  8.93347558e-05,
#        -3.52004070e-05])

# %%
train_rmse_errors = []
test_rmse_errors = []

for d in range(1,10):
    poly_converter = PolynomialFeatures(degree=d, include_bias=False)
    poly_features = poly_converter.fit_transform(x1)
    X_train, X_test, y_train, y_test = train_test_split(
                                    poly_features, y, test_size=0.33, random_state=101)

    model = LinearRegression()
    model.fit(X_train, y_train)

    train_pred = model.predict(X_train)
    test_pred = model.predict(X_test)

    train_rmse = np.sqrt(mean_squared_error(y_train, train_pred))
    test_rmse = np.sqrt(mean_squared_error(y_test, test_pred))
    

    train_rmse_errors.append(train_rmse)
    test_rmse_errors.append(test_rmse)

# %%
train_rmse_errors
# Out:
# [1.7376515982447711,
#  0.5947926597019145,
#  0.44059734232363623,
#  0.353291328203811,
#  0.24845372122354306,
#  0.18843554448378907,
#  4.831415603879643,
#  0.15488304895899166,
#  0.15134000446817175]

# %%
test_rmse_errors #overfitting is happening after the 5th degree(error exploding)
# Out:
# [1.5324409426512415,
#  0.6482912032533633,
#  0.5577254823367401,
#  0.5064297300349341,
#  2.3573691979064946,
#  11.249004146863413,
#  1207.855338620503,
#  3237.5158278306517,
#  174700.91661863212]

# %%
plt.plot(range(1,6), train_rmse_errors[:5], label = 'TRAIN_RMSE') #You will be selecting the 2nd degree polynomial model
plt.plot(range(1,6), test_rmse_errors[:5], label = 'TEST_RMSE')
plt.xlabel("Model Complexity/ Degree of Polynomial")
plt.ylabel("RMSE")
plt.legend()

# %%
plt.plot(range(1,10), train_rmse_errors, label = 'TRAIN_RMSE')
plt.plot(range(1,10), test_rmse_errors, label = 'TEST_RMSE')
plt.xlabel("Model Complexity/ Degree of Polynomial")
plt.ylabel("RMSE")
plt.legend()

# %%
final_poly_converter = PolynomialFeatures(degree=3, include_bias=False)

# %%
final_model = LinearRegression()

# %%
full_converted_x = final_poly_converter.fit_transform(x)
final_model.fit(full_converted_x, y)
# Out:
# LinearRegression()

# %%
model_dir = "models"
os.makedirs(model_dir, exist_ok=True)
filepath = os.path.join(model_dir, 'poly.joblib')
dump(final_model, filepath)
# Out:
# ['models\\poly.joblib']

# %%
model_dir = "models"
os.makedirs(model_dir, exist_ok=True)
filepath = os.path.join(model_dir, 'final_poly_converter.joblib')
dump(final_poly_converter, filepath)
# Out:
# ['models\\final_poly_converter.joblib']

# %%
loaded_converter = load(r'C:\Users\Sagar Kandpal\Desktop\ML EXAMPLE\Modular\ML_Live_Class\models\final_poly_converter.joblib')

# %%
loaded_model = load(r"C:\Users\Sagar Kandpal\Desktop\ML EXAMPLE\Modular\ML_Live_Class\models\poly.joblib")
